# %%
def get_join_keys(table_name,join_keys):
        for d in join_keys:
                for f,k in d.items():
                        if(f==table_name):
                                join_expr = " AND ".join([f"l.bronze_{c} = r.{c} " for c in k])
        
        return join_expr

def get_merge_keys(table_name,join_keys):
        for d in join_keys:
                for f,k in d.items():
                        if(f==table_name):
                                merge_expr = " AND ".join([f"t.{c} = u.{c} " for c in k])

        return merge_expr
